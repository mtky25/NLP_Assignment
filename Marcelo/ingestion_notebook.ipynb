# %% [markdown]
# ## **Ingestion**

# %%
from src.guesser.ingestion.pipelines.zim_ingestion import ZimIngestionPipeline
from src.guesser.configs import EMBEDDING_MODEL

# %%
DB_PATH = "Marcelo/src/guesser/context_db/"
FILE_PATH = "src/guesser/data/raw/wikipedia_en_100_nopic_2026-04.zim"
COLLECTION_NAME = "general"

# %%
extractor = ZimIngestionPipeline(raw_data_file_path=FILE_PATH,embedding_model=EMBEDDING_MODEL,db_path=DB_PATH,colletion_name=COLLECTION_NAME)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 extractor = ZimIngestionPipeline("src/guesser/data/raw/wikipedia_en_100_nopic_2026-04.zim",embedding_model=EMBEDDING_MODEL,db_path=DB_PATH,colletion_name="General")
#
# File c:\Users\marce\Desktop\Code\NLP_Assignment\Marcelo\src\guesser\ingestion\pipelines\zim_ingestion.py:9, in ZimIngestionPipeline.__init__(self, raw_data_file_path, embedding_model, db_path, colletion_name)
#       7 self.path = raw_data_file_path
#       8 self.extractor = ZimExtractor(raw_data_file_path)
# ----> 9 self.loader = Loader(
#      10                     db_path=db_path,
#      11                     embedding_model_name=embedding_model,
#      12                     collection_name=colletion_name)
#
# TypeError: Loader.__init__() got an unexpected keyword argument 'collection_name'

# %%
extractor.count_archives()
# Out:
# 'Total of Articles: 5175'

# %%
extractor.extract(100)
