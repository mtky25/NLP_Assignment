# %% [markdown]
# ## **Ingestion**

# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.guesser.ingestion.pipelines.zim_ingestion import ZimIngestionPipeline
from src.guesser.configs import EMBEDDING_MODEL
from src.guesser.ingestion.extractors.zim_extractor import ZimExtractor
from src.guesser.context_db.collections import (
    COLLECTION_MATH,
    COLLECTION_DEFAULT,
    COLLECTION_ENTERTAINMENT,
    COLLECTION_HISTORY,
    COLLECTION_SCIENCE
)

# %%
DB_PATH = "src/guesser/context_db/"
FILE_PATH = "src/guesser/data/raw/ancient_history_and_politics/wikipedia_en_history_nopic_2026-04.zim"
COLLECTION_NAME = COLLECTION_HISTORY

# %%
ingestor = ZimIngestionPipeline(raw_data_file_path=FILE_PATH,embedding_model=EMBEDDING_MODEL,db_path=DB_PATH,colletion_name=COLLECTION_NAME)

# %%
ingestor.extractor.count_archives()
# Out:
# 'Total of Articles: 225635'

# %%
await ingestor.process(500,batch_size=50,summary_only=True)
# Out:
# Starting async ZIM ingestion (limit=500, batch_size=50, summary_only=True, num_paragraphs=10)...
# [50/500] Processing batch of 50 documents...
#  -> Generated 159 nodes. Loading into ChromaDB...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 await ingestor.process(500,batch_size=50,summary_only=True)
#
# File c:\Users\marce\Desktop\Code\NLP_Assignment\Marcelo\src\guesser\ingestion\pipelines\zim_ingestion.py:32, in ZimIngestionPipeline.process(self, limit, starting_id, batch_size, summary_only, num_paragraphs)
#      30         total_nodes += len(nodes)
#      31         print(f" -> Generated {len(nodes)} nodes. Loading into ChromaDB...")
# ---> 32         await self.loader.aload_nodes(nodes, collection_name=self.collection_name)
#      33         current_batch = []
#      35 # Process remaining
#
# ...
